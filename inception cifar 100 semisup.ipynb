# %%
import os
import argparse
import logging
logging.basicConfig(level=logging.DEBUG)
from common import find_mxnet, data, fit
from common.util import download_file
import mxnet as mx
# Out:
# /usr/lib/python3.4/json/encoder.py:192: DeprecationWarning: Interpreting naive datetime as local 2017-05-22 08:32:19.413043. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
def download_cifar10():
    data_dir="/efs/data/cifar-100-mxnet"
    #data_dir="/data/cifar-100-mxnet"
    fnames = (os.path.join(data_dir, "train.rec"),
              os.path.join(data_dir, "test.rec"))
    return fnames
# Out:
# /usr/lib/python3.4/json/encoder.py:192: DeprecationWarning: Interpreting naive datetime as local 2017-05-22 08:32:20.441728. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
(train_fname, val_fname) = download_cifar10()

# parse args
parser = argparse.ArgumentParser(description="train cifar100",
                                 formatter_class=argparse.ArgumentDefaultsHelpFormatter)
fit.add_fit_args(parser)
data.add_data_args(parser)
data.add_data_aug_args(parser)
data.set_data_aug_level(parser, 2)
parser.set_defaults(
    # data
    data_train     = train_fname,
    data_val       = val_fname,
    num_classes    = 100,
    num_examples  = 50000,
    image_shape    = '3,28,28',
 #   model_prefix   = '/efs/checkpoints/inceptionStandard',
    pad_size       = 4,
    # train
    batch_size     = 128,
    num_epochs     = 45,
    lr             = .05,
    lr_step_epochs = '38',
    gpus           = '4,5,6,7'
)
args = parser.parse_args("")
# Out:
# /usr/lib/python3.4/json/encoder.py:192: DeprecationWarning: Interpreting naive datetime as local 2017-05-22 08:32:20.446772. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
from mxnet.io import DataDesc

#todo unsupervised should not contain the supervised samples
#(trainUnsup, valUnsup) = data.get_rec_iter(args)

#train = mx.io.PrefetchingIter([trainSup, trainUnsup],
#                        rename_data=[{'data': 'dataSup'}, 
#                                     {'data': 'dataUnsup'}],
#                        rename_label=[{'softmax_label': 'labelSup'}, 
#                                     {'softmax_label': 'labelUnsup'}])
sup_batch_size = 128
unsup_multiplier = 1

args.batch_size = sup_batch_size * (unsup_multiplier+1)
(train, val) = data.get_rec_iter(args, shuffle=False)


class Split_Iterator(mx.io.DataIter):
    '''splits dataset into supervised and unsupervised part'''

    def __init__(self, data_iter):
        super(Split_Iterator, self).__init__()
        self.data_iter = data_iter
        self.batch_size = self.data_iter.batch_size

    @property
    def provide_data(self):
        data = [DataDesc('dataSup', (sup_batch_size,3,28,28), 'float32')]
        return data + [DataDesc('dataUnsup'+str(i), (sup_batch_size,3,28,28), 'float32') for i in range(unsup_multiplier)]
        
    @property
    def provide_label(self):
        return [DataDesc('labelSup', (sup_batch_size,), 'float32')]

    def hard_reset(self):
        self.data_iter.hard_reset()

    def reset(self):
        self.data_iter.reset()

    def next(self):
        batch = self.data_iter.next()
        
        if unsup_multiplier >= 1:
        
            data = batch.data[0]
            labels = batch.label[0]

            dataSplits = mx.ndarray.split(data, axis=0, num_outputs=(unsup_multiplier+1))
            labelSplits = mx.ndarray.split(labels, axis=0, num_outputs=(unsup_multiplier+1))

            # todo shuffling, does not make sense in a minibatch           
            
            return mx.io.DataBatch(data=dataSplits, label=[labelSplits[0]], \
                        pad=batch.pad, index=batch.index)
        else:
            return mx.io.DataBatch(data=batch.data, label=batch.label, \
                pad=batch.pad, index=batch.index)

            
splittedTrainData = Split_Iterator(train)
# Out:
# /usr/lib/python3.4/json/encoder.py:192: DeprecationWarning: Interpreting naive datetime as local 2017-05-22 08:32:20.456960. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
def ConvFactory(data, num_filter, kernel, stride=(1,1), pad=(0, 0), name=None, suffix=''):
    conv = mx.symbol.Convolution(data=data, num_filter=num_filter, kernel=kernel, stride=stride, pad=pad, name='conv_%s%s' %(name, suffix))
    bn = mx.symbol.BatchNorm(data=conv, name='bn_%s%s' %(name, suffix))
    act = mx.symbol.LeakyReLU(data=bn, act_type='rrelu', name='rrelu_%s%s' %(name, suffix))
    return act

def InceptionFactoryA(data, num_1x1, num_3x3red, num_3x3, num_d3x3red, num_d3x3, pool, proj, name):
    # 1x1
    c1x1 = ConvFactory(data=data, num_filter=num_1x1, kernel=(1, 1), name=('%s_1x1' % name))
    # 3x3 reduce + 3x3
    c3x3r = ConvFactory(data=data, num_filter=num_3x3red, kernel=(1, 1), name=('%s_3x3' % name), suffix='_reduce')
    c3x3 = ConvFactory(data=c3x3r, num_filter=num_3x3, kernel=(3, 3), pad=(1, 1), name=('%s_3x3' % name))
    # double 3x3 reduce + double 3x3
    cd3x3r = ConvFactory(data=data, num_filter=num_d3x3red, kernel=(1, 1), name=('%s_double_3x3' % name), suffix='_reduce')
    cd3x3 = ConvFactory(data=cd3x3r, num_filter=num_d3x3, kernel=(3, 3), pad=(1, 1), name=('%s_double_3x3_0' % name))
    cd3x3 = ConvFactory(data=cd3x3, num_filter=num_d3x3, kernel=(3, 3), pad=(1, 1), name=('%s_double_3x3_1' % name))
    # pool + proj
    pooling = mx.symbol.Pooling(data=data, kernel=(3, 3), stride=(1, 1), pad=(1, 1), pool_type=pool, name=('%s_pool_%s_pool' % (pool, name)))
    cproj = ConvFactory(data=pooling, num_filter=proj, kernel=(1, 1), name=('%s_proj' %  name))
    # concat
    concat = mx.symbol.Concat(*[c1x1, c3x3, cd3x3, cproj], name='ch_concat_%s_chconcat' % name)
    return concat

def InceptionFactoryB(data, num_3x3red, num_3x3, num_d3x3red, num_d3x3, name):
    # 3x3 reduce + 3x3
    c3x3r = ConvFactory(data=data, num_filter=num_3x3red, kernel=(1, 1), name=('%s_3x3' % name), suffix='_reduce')
    c3x3 = ConvFactory(data=c3x3r, num_filter=num_3x3, kernel=(3, 3), pad=(1, 1), stride=(2, 2), name=('%s_3x3' % name))
    # double 3x3 reduce + double 3x3
    cd3x3r = ConvFactory(data=data, num_filter=num_d3x3red, kernel=(1, 1),  name=('%s_double_3x3' % name), suffix='_reduce')
    cd3x3 = ConvFactory(data=cd3x3r, num_filter=num_d3x3, kernel=(3, 3), pad=(1, 1), stride=(1, 1), name=('%s_double_3x3_0' % name))
    cd3x3 = ConvFactory(data=cd3x3, num_filter=num_d3x3, kernel=(3, 3), pad=(1, 1), stride=(2, 2), name=('%s_double_3x3_1' % name))
    # pool + proj
    pooling = mx.symbol.Pooling(data=data, kernel=(3, 3), stride=(2, 2), pad=(1,1), pool_type="max", name=('max_pool_%s_pool' % name))
    # concat
    concat = mx.symbol.Concat(*[c3x3, cd3x3, pooling], name='ch_concat_%s_chconcat' % name)
    return concat
# Out:
# /usr/lib/python3.4/json/encoder.py:192: DeprecationWarning: Interpreting naive datetime as local 2017-05-22 08:32:20.749742. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
def build_embeddings(data, nembeddings, grad_scale=1.0):
    # data
    #data = mx.symbol.Variable(name="data")
    # stage 2
    in3a = InceptionFactoryA(data, 64, 64, 64, 64, 96, "avg", 32, '3a')
    in3b = InceptionFactoryA(in3a, 64, 64, 96, 64, 96, "avg", 64, '3b')
    in3c = InceptionFactoryB(in3b, 128, 160, 64, 96, '3c')
    # stage 3
    in4a = InceptionFactoryA(in3c, 224, 64, 96, 96, 128, "avg", 128, '4a')
    in4b = InceptionFactoryA(in4a, 192, 96, 128, 96, 128, "avg", 128, '4b')
    in4c = InceptionFactoryA(in4b, 160, 128, 160, 128, 160, "avg", 128, '4c')
    in4d = InceptionFactoryA(in4c, 96, 128, 192, 160, 192, "avg", 128, '4d')
    in4e = InceptionFactoryB(in4d, 128, 192, 192, 256, '4e')
    # stage 4
    in5a = InceptionFactoryA(in4e, 352, 192, 320, 160, 224, "avg", 128, '5a')
    in5b = InceptionFactoryA(in5a, 352, 192, 320, 192, 224, "max", 128, '5b')
    # global avg pooling
    avg = mx.symbol.Pooling(data=in5b, kernel=(7, 7), stride=(1, 1), name="global_pool", pool_type='avg')
    # linear classifier
    flatten = mx.symbol.Flatten(data=avg, name='flatten')
    
    #flatten has 1024 outputs
    #arg_shape, output_shape, aux_shape = flatten.infer_shape(data=(1, 3,28,28))
    #print(output_shape)
    
    # nice and smooth embeddings
    fc0 = mx.symbol.FullyConnected(data=flatten, num_hidden=nembeddings, name='fc0') 
    return fc0
# Out:
# /usr/lib/python3.4/json/encoder.py:192: DeprecationWarning: Interpreting naive datetime as local 2017-05-22 08:32:20.797161. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
from mxnet.symbol import *

def getshape(tensor):
    arg_shape, output_shape, aux_shape = tensor.infer_shape(labelSup=(128,))
    print(output_shape)
def getshapeData(tensor):
    arg_shape, output_shape, aux_shape = tensor.infer_shape(
        dataUnsup=(128,3,28,28),dataSup=(128,3,28,28))
    print(output_shape)
    
def compute_visit_loss(p, visit_weight=1):
    
    visit_probability = mean(p, axis=(0), keepdims=True, name='visit_prob')
    
    t_nb = sup_batch_size * unsup_multiplier
    
    init = mx.initializer.Constant(t_nb)
    t_nb = var('t_nb', init=init, dtype='float32', shape=(1))
    
    target = broadcast_div(ones_like(visit_probability), t_nb)
    
    arg_shape, output_shape, aux_shape = visit_probability.infer_shape(
        dataUnsup0=(128,3,28,28),dataSup=(128,3,28,28))
    print(output_shape)
    arg_shape, output_shape, aux_shape = target.infer_shape(
        dataUnsup0=(128,3,28,28),dataSup=(128,3,28,28))
    print(output_shape)
    arg_shape, output_shape, aux_shape = t_nb.infer_shape()
    print(output_shape)
    
    visit_loss = SoftmaxOutput(visit_probability, target, grad_scale=visit_weight, name='visit_loss')
    
    return visit_loss
    
def compute_semisup_loss(a,b,labels,walker_weight=1., visit_weight=1.):
    equality_matrix = broadcast_equal(reshape(labels, shape=(-1,1)), labels, name="eqmat")
    
    equality_matrix = cast(equality_matrix, dtype='float32')
    p_target = broadcast_div(equality_matrix,
                             sum(equality_matrix, axis=(1), keepdims=True))
    
    match_ab = dot(a,transpose(b),name='match_ab')
    p_ab = softmax(match_ab, name='p_ab')
    p_ba = softmax(transpose(match_ab), name='p_ba')
    p_aba = dot(p_ab, p_ba, name='p_aba')
    
    #todo: create walk statistics
    
    # softmaxOutput should be cross entropy loss: https://github.com/dmlc/mxnet/issues/1969
    # apparently this calculates the gradient of cross entropy loss for backprop, so should
    # be equivalent
    
    # probably no need to log: l = log(1e-8 + p_aba, name='log_aba')
    
    walker_loss = SoftmaxOutput(p_aba, p_target, name='loss_aba', grad_scale=walker_weight)
    
    # this would be some kind of cross entropy loss. does not work yet though
    #cross_entropy = p_target * log(out) + (1 - p_target) * log(1 - out)
    #loss = MakeLoss(cross_entropy)
    
    visit_loss = compute_visit_loss(p_ab, visit_weight)

    return (walker_loss, visit_loss)
# Out:
# /usr/lib/python3.4/json/encoder.py:192: DeprecationWarning: Interpreting naive datetime as local 2017-05-22 08:32:20.822029. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
def logit_loss(embeddings, labels, nclasses, grad_scale=1):
    fc1 = mx.symbol.FullyConnected(data=embeddings, num_hidden=nclasses, name='fc1'+str(grad_scale))
    softmax = mx.symbol.SoftmaxOutput(fc1, labels, name='softmax'+str(grad_scale), grad_scale=grad_scale)
    return softmax
# Out:
# /usr/lib/python3.4/json/encoder.py:192: DeprecationWarning: Interpreting naive datetime as local 2017-05-22 08:32:20.884320. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
def build():
    dataSup = mx.symbol.Variable(name="dataSup")
    labelSup = mx.symbol.Variable(name='labelSup')
    overall_loss = []
    
    if unsup_multiplier >= 1:
        dataUnsup = mx.symbol.Variable(name="dataUnsup0")

        # concat data, feed both through the network
        # then split it up again
        data = concat(dataSup, dataUnsup, dim=0)

        embeddings = build_embeddings(data, nembeddings=256)
        splitted = split(embeddings, num_outputs=(unsup_multiplier+1), axis=0)

        supEmbeddings = splitted[0]
        unsupEmbeddings = splitted[1]
        (walker_loss, visit_loss) = compute_semisup_loss(supEmbeddings, unsupEmbeddings, labelSup, 
                                                     walker_weight=0.5, visit_weight=0.5)
        overall_loss = [walker_loss, visit_loss]
        
    else:
        supEmbeddings = build_embeddings(dataSup, nembeddings=256)
        
    overall_loss = [logit_loss(supEmbeddings, labelSup, 100)] + overall_loss
    
    return Group(overall_loss)
# Out:
# /usr/lib/python3.4/json/encoder.py:192: DeprecationWarning: Interpreting naive datetime as local 2017-05-22 08:32:20.889637. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
class Multi_Accuracy(mx.metric.EvalMetric):
    """Calculate accuracies of multi label"""

    def __init__(self, num=None):
        super(Multi_Accuracy, self).__init__('multi-accuracy', num)

    def update(self, labels, preds):

        for i in range(len(preds)):
            pred_label = mx.nd.argmax_channel(preds[i]).asnumpy().astype('int32')
            label = labels[0].asnumpy().astype('int32')

            #mx.metric.check_label_shapes(label, pred_label)

            if i is None:
                self.sum_metric += (pred_label.flat == label.flat).sum()
                self.num_inst += len(pred_label.flat)
            else:
                self.sum_metric[i] += (pred_label.flat == label.flat).sum()
                self.num_inst[i] += len(pred_label.flat)
# Out:
# /usr/lib/python3.4/json/encoder.py:192: DeprecationWarning: Interpreting naive datetime as local 2017-05-22 08:32:20.904665. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
def fit_model(args, network, data, **kwargs):
    """
    train a model
    args : argparse returns
    network : the symbol definition of the nerual network
    data_loader : function that returns the train and val data iterators
    """
    # kvstore
    kv = mx.kvstore.create(args.kv_store)

    # logging
    head = '%(asctime)-15s Node[' + str(kv.rank) + '] %(message)s'
    logging.basicConfig(level=logging.DEBUG, format=head)
    logging.info('start with arguments %s', args)

    # data iterators
    (train, val) = data
    if args.test_io:
        tic = time.time()
        for i, batch in enumerate(train):
            for j in batch.data:
                j.wait_to_read()
            if (i+1) % args.disp_batches == 0:
                logging.info('Batch [%d]\tSpeed: %.2f samples/sec' % (
                    i, args.disp_batches*args.batch_size/(time.time()-tic)))
                tic = time.time()
        return

    # load model
    if 'arg_params' in kwargs and 'aux_params' in kwargs:
        arg_params = kwargs['arg_params']
        aux_params = kwargs['aux_params']
    else:
        sym, arg_params, aux_params = fit._load_model(args, kv.rank)
        if sym is not None:
            assert sym.tojson() == network.tojson()

    # save model
    checkpoint = fit._save_model(args, kv.rank)

    # devices for training
    devs = mx.cpu() if args.gpus is None or args.gpus is '' else [
        mx.gpu(int(i)) for i in args.gpus.split(',')]

    # learning rate
    lr, lr_scheduler = fit._get_lr_scheduler(args, kv)

    data_names = ['dataSup'] + ['dataUnsup'+str(i) for i in range(unsup_multiplier)]
    # create model
    model = mx.mod.Module(
        context       = devs,
        symbol        = network,
        label_names   = ['labelSup'],
        data_names   = data_names
    )
    
    #print(model.label_names)
    lr_scheduler  = lr_scheduler
    optimizer_params = {
            'learning_rate': lr,
            'momentum' : args.mom,
            'wd' : args.wd,
            'lr_scheduler': lr_scheduler}

    monitor = mx.mon.Monitor(interval=1000, pattern='.*aba_backward.*') 
    
    initializer = mx.init.Xavier(
        rnd_type='gaussian', factor_type="in", magnitude=2)
    # initializer   = mx.init.Xavier(factor_type="in", magnitude=2.34),

    # evaluation metrices
    eval_metrics = Multi_Accuracy(num=3)

    # callbacks that run after each batch
    batch_end_callbacks = [mx.callback.Speedometer(args.batch_size, args.disp_batches)]

    # run
    model.fit(train,
        begin_epoch        = args.load_epoch if args.load_epoch else 0,
        num_epoch          = args.num_epochs,
        eval_data          = val,
        eval_metric        = eval_metrics,
        kvstore            = kv,
        optimizer          = args.optimizer,
        optimizer_params   = optimizer_params,
        initializer        = initializer,
        arg_params         = arg_params,
        aux_params         = aux_params,
        batch_end_callback = batch_end_callbacks,
        epoch_end_callback = checkpoint,
        allow_missing      = True,
        monitor            = monitor)
    return model
# Out:
# /usr/lib/python3.4/json/encoder.py:192: DeprecationWarning: Interpreting naive datetime as local 2017-05-22 08:32:20.919091. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
inception = build()

model = fit_model(args, inception, (splittedTrainData, val))
# Out:
# INFO:root:start with arguments Namespace(batch_size=256, benchmark=0, data_nthreads=4, data_train='/efs/data/cifar-100-mxnet/train.rec', data_val='/efs/data/cifar-100-mxnet/test.rec', disp_batches=20, dtype='float32', gpus='4,5,6,7', image_shape='3,28,28', kv_store='device', load_epoch=None, lr=0.05, lr_factor=0.1, lr_step_epochs='38', max_random_aspect_ratio=0, max_random_h=36, max_random_l=50, max_random_rotate_angle=0, max_random_s=50, max_random_scale=1, max_random_shear_ratio=0, min_random_scale=1, model_prefix=None, mom=0.9, monitor=0, network=None, num_classes=100, num_epochs=45, num_examples=50000, num_layers=None, optimizer='sgd', pad_size=4, random_crop=1, random_mirror=1, rgb_mean='123.68,116.779,103.939', test_io=0, top_k=0, wd=0.0001)
# [(1, 128)]
# [(1, 128)]
# [(1,)]
# INFO:root:Batch:       1 loss_aba_backward_data         0.0794742
# INFO:root:Batch:       1 loss_aba_backward_label        0.0754529
# INFO:root:Batch:       1 p_aba_backward_0               0.0575235
# INFO:root:Batch:       1 p_aba_backward_1               0.0646825
# INFO:root:Batch:       1 loss_aba_backward_data         0.0838479
# INFO:root:Batch:       1 loss_aba_backward_label        0.0682083
# INFO:root:Batch:       1 p_aba_backward_0               0.0802431
# INFO:root:Batch:       1 p_aba_backward_1               0.0714157
# INFO:root:Batch:       1 loss_aba_backward_data         0.0794634
# INFO:root:Batch:       1 loss_aba_backward_label        0.0743439
# INFO:root:Batch:       1 p_aba_backward_0               0.0650386
# INFO:root:Batch:       1 p_aba_backward_1               0.0649255
# INFO:root:Batch:       1 loss_aba_backward_data         0.0826275
# INFO:root:Batch:       1 loss_aba_backward_label        0.0665453
# INFO:root:Batch:       1 p_aba_backward_0               0.0751238
# INFO:root:Batch:       1 p_aba_backward_1               0.0613855
# INFO:root:Epoch[0] Batch [20]	Speed: 476.62 samples/sec	Train-multi-accuracy_0=0.021949
# INFO:root:Epoch[0] Batch [20]	Speed: 476.62 samples/sec	Train-multi-accuracy_1=0.011161
# INFO:root:Epoch[0] Batch [20]	Speed: 476.62 samples/sec	Train-multi-accuracy_2=0.297619
# INFO:root:Epoch[0] Batch [40]	Speed: 459.21 samples/sec	Train-multi-accuracy_0=0.032813
# INFO:root:Epoch[0] Batch [40]	Speed: 459.21 samples/sec	Train-multi-accuracy_1=0.011719
# INFO:root:Epoch[0] Batch [40]	Speed: 459.21 samples/sec	Train-multi-accuracy_2=0.212500
# INFO:root:Epoch[0] Batch [60]	Speed: 459.28 samples/sec	Train-multi-accuracy_0=0.041016
# INFO:root:Epoch[0] Batch [60]	Speed: 459.28 samples/sec	Train-multi-accuracy_1=0.010547
# INFO:root:Epoch[0] Batch [60]	Speed: 459.28 samples/sec	Train-multi-accuracy_2=0.375000
# INFO:root:Epoch[0] Batch [80]	Speed: 457.58 samples/sec	Train-multi-accuracy_0=0.044531
# INFO:root:Epoch[0] Batch [80]	Speed: 457.58 samples/sec	Train-multi-accuracy_1=0.010156
# INFO:root:Epoch[0] Batch [80]	Speed: 457.58 samples/sec	Train-multi-accuracy_2=0.262500
# INFO:root:Epoch[0] Batch [100]	Speed: 458.20 samples/sec	Train-multi-accuracy_0=0.048438
# INFO:root:Epoch[0] Batch [100]	Speed: 458.20 samples/sec	Train-multi-accuracy_1=0.011719
# INFO:root:Epoch[0] Batch [100]	Speed: 458.20 samples/sec	Train-multi-accuracy_2=0.337500
# INFO:root:Epoch[0] Batch [120]	Speed: 457.69 samples/sec	Train-multi-accuracy_0=0.058594
# INFO:root:Epoch[0] Batch [120]	Speed: 457.69 samples/sec	Train-multi-accuracy_1=0.012891
# INFO:root:Epoch[0] Batch [120]	Speed: 457.69 samples/sec	Train-multi-accuracy_2=0.275000
# INFO:root:Epoch[0] Batch [140]	Speed: 459.30 samples/sec	Train-multi-accuracy_0=0.057422
# INFO:root:Epoch[0] Batch [140]	Speed: 459.30 samples/sec	Train-multi-accuracy_1=0.008984
# INFO:root:Epoch[0] Batch [140]	Speed: 459.30 samples/sec	Train-multi-accuracy_2=0.412500
# INFO:root:Epoch[0] Batch [160]	Speed: 460.27 samples/sec	Train-multi-accuracy_0=0.067969
# INFO:root:Epoch[0] Batch [160]	Speed: 460.27 samples/sec	Train-multi-accuracy_1=0.014063
# INFO:root:Epoch[0] Batch [160]	Speed: 460.27 samples/sec	Train-multi-accuracy_2=0.350000
# INFO:root:Epoch[0] Batch [180]	Speed: 459.94 samples/sec	Train-multi-accuracy_0=0.068359
# INFO:root:Epoch[0] Batch [180]	Speed: 459.94 samples/sec	Train-multi-accuracy_1=0.007422
# INFO:root:Epoch[0] Batch [180]	Speed: 459.94 samples/sec	Train-multi-accuracy_2=0.262500
# INFO:root:Epoch[0] Train-multi-accuracy_0=0.067708
# INFO:root:Epoch[0] Train-multi-accuracy_1=0.009375
# INFO:root:Epoch[0] Train-multi-accuracy_2=0.433333
# INFO:root:Epoch[0] Time cost=112.038
# INFO:root:Epoch[0] Validation-multi-accuracy_0=0.102344
# INFO:root:Epoch[0] Validation-multi-accuracy_1=0.009766
# INFO:root:Epoch[0] Validation-multi-accuracy_2=0.306250
# INFO:root:Epoch[1] Batch [20]	Speed: 460.28 samples/sec	Train-multi-accuracy_0=0.079985
# INFO:root:Epoch[1] Batch [20]	Speed: 460.28 samples/sec	Train-multi-accuracy_1=0.014137
# INFO:root:Epoch[1] Batch [20]	Speed: 460.28 samples/sec	Train-multi-accuracy_2=0.261905
# INFO:root:Epoch[1] Batch [40]	Speed: 459.78 samples/sec	Train-multi-accuracy_0=0.073438
# INFO:root:Epoch[1] Batch [40]	Speed: 459.78 samples/sec	Train-multi-accuracy_1=0.008984
# INFO:root:Epoch[1] Batch [40]	Speed: 459.78 samples/sec	Train-multi-accuracy_2=0.325000
# INFO:root:Epoch[1] Batch [60]	Speed: 458.70 samples/sec	Train-multi-accuracy_0=0.087891
# INFO:root:Epoch[1] Batch [60]	Speed: 458.70 samples/sec	Train-multi-accuracy_1=0.011719
# INFO:root:Epoch[1] Batch [60]	Speed: 458.70 samples/sec	Train-multi-accuracy_2=0.300000
# INFO:root:Epoch[1] Batch [80]	Speed: 458.03 samples/sec	Train-multi-accuracy_0=0.098828
# INFO:root:Epoch[1] Batch [80]	Speed: 458.03 samples/sec	Train-multi-accuracy_1=0.010156
# INFO:root:Epoch[1] Batch [80]	Speed: 458.03 samples/sec	Train-multi-accuracy_2=0.300000
# INFO:root:Epoch[1] Batch [100]	Speed: 457.51 samples/sec	Train-multi-accuracy_0=0.092578
# INFO:root:Epoch[1] Batch [100]	Speed: 457.51 samples/sec	Train-multi-accuracy_1=0.007812
# INFO:root:Epoch[1] Batch [100]	Speed: 457.51 samples/sec	Train-multi-accuracy_2=0.375000
# INFO:root:Epoch[1] Batch [120]	Speed: 457.99 samples/sec	Train-multi-accuracy_0=0.102734
# INFO:root:Epoch[1] Batch [120]	Speed: 457.99 samples/sec	Train-multi-accuracy_1=0.009766
# INFO:root:Epoch[1] Batch [120]	Speed: 457.99 samples/sec	Train-multi-accuracy_2=0.437500
# INFO:root:Epoch[1] Batch [140]	Speed: 458.16 samples/sec	Train-multi-accuracy_0=0.101562
# INFO:root:Epoch[1] Batch [140]	Speed: 458.16 samples/sec	Train-multi-accuracy_1=0.005859
# INFO:root:Epoch[1] Batch [140]	Speed: 458.16 samples/sec	Train-multi-accuracy_2=0.400000
# INFO:root:Epoch[1] Batch [160]	Speed: 458.42 samples/sec	Train-multi-accuracy_0=0.097266
# INFO:root:Epoch[1] Batch [160]	Speed: 458.42 samples/sec	Train-multi-accuracy_1=0.008594
# INFO:root:Epoch[1] Batch [160]	Speed: 458.42 samples/sec	Train-multi-accuracy_2=0.325000
# INFO:root:Epoch[1] Batch [180]	Speed: 457.68 samples/sec	Train-multi-accuracy_0=0.111719
# INFO:root:Epoch[1] Batch [180]	Speed: 457.68 samples/sec	Train-multi-accuracy_1=0.010547
# INFO:root:Epoch[1] Batch [180]	Speed: 457.68 samples/sec	Train-multi-accuracy_2=0.437500
# INFO:root:Epoch[1] Train-multi-accuracy_0=0.108259
# INFO:root:Epoch[1] Train-multi-accuracy_1=0.006696
# INFO:root:Epoch[1] Train-multi-accuracy_2=0.464286
# INFO:root:Epoch[1] Time cost=108.546
# INFO:root:Epoch[1] Validation-multi-accuracy_0=0.141426
# INFO:root:Epoch[1] Validation-multi-accuracy_1=0.009615
# INFO:root:Epoch[1] Validation-multi-accuracy_2=0.320513
# INFO:root:Epoch[2] Batch [20]	Speed: 458.29 samples/sec	Train-multi-accuracy_0=0.111235
# INFO:root:Epoch[2] Batch [20]	Speed: 458.29 samples/sec	Train-multi-accuracy_1=0.008557
# INFO:root:Epoch[2] Batch [20]	Speed: 458.29 samples/sec	Train-multi-accuracy_2=0.285714
# INFO:root:Epoch[2] Batch [40]	Speed: 458.27 samples/sec	Train-multi-accuracy_0=0.129688
# INFO:root:Epoch[2] Batch [40]	Speed: 458.27 samples/sec	Train-multi-accuracy_1=0.010156
# INFO:root:Epoch[2] Batch [40]	Speed: 458.27 samples/sec	Train-multi-accuracy_2=0.312500
# INFO:root:Epoch[2] Batch [60]	Speed: 458.90 samples/sec	Train-multi-accuracy_0=0.137891
# INFO:root:Epoch[2] Batch [60]	Speed: 458.90 samples/sec	Train-multi-accuracy_1=0.008203
# INFO:root:Epoch[2] Batch [60]	Speed: 458.90 samples/sec	Train-multi-accuracy_2=0.350000
# INFO:root:Epoch[2] Batch [80]	Speed: 458.48 samples/sec	Train-multi-accuracy_0=0.139063
# INFO:root:Epoch[2] Batch [80]	Speed: 458.48 samples/sec	Train-multi-accuracy_1=0.010547
# INFO:root:Epoch[2] Batch [80]	Speed: 458.48 samples/sec	Train-multi-accuracy_2=0.350000
# INFO:root:Epoch[2] Batch [100]	Speed: 458.12 samples/sec	Train-multi-accuracy_0=0.137500
# INFO:root:Epoch[2] Batch [100]	Speed: 458.12 samples/sec	Train-multi-accuracy_1=0.008594
# INFO:root:Epoch[2] Batch [100]	Speed: 458.12 samples/sec	Train-multi-accuracy_2=0.350000
# INFO:root:Epoch[2] Batch [120]	Speed: 458.57 samples/sec	Train-multi-accuracy_0=0.135547
# INFO:root:Epoch[2] Batch [120]	Speed: 458.57 samples/sec	Train-multi-accuracy_1=0.007422
# INFO:root:Epoch[2] Batch [120]	Speed: 458.57 samples/sec	Train-multi-accuracy_2=0.375000
# INFO:root:Epoch[2] Batch [140]	Speed: 458.05 samples/sec	Train-multi-accuracy_0=0.144922
# INFO:root:Epoch[2] Batch [140]	Speed: 458.05 samples/sec	Train-multi-accuracy_1=0.011719
# INFO:root:Epoch[2] Batch [140]	Speed: 458.05 samples/sec	Train-multi-accuracy_2=0.350000
# INFO:root:Epoch[2] Batch [160]	Speed: 458.09 samples/sec	Train-multi-accuracy_0=0.146484
# INFO:root:Epoch[2] Batch [160]	Speed: 458.09 samples/sec	Train-multi-accuracy_1=0.006250
# INFO:root:Epoch[2] Batch [160]	Speed: 458.09 samples/sec	Train-multi-accuracy_2=0.262500
# INFO:root:Epoch[2] Batch [180]	Speed: 457.79 samples/sec	Train-multi-accuracy_0=0.153516
# INFO:root:Epoch[2] Batch [180]	Speed: 457.79 samples/sec	Train-multi-accuracy_1=0.010547
# INFO:root:Epoch[2] Batch [180]	Speed: 457.79 samples/sec	Train-multi-accuracy_2=0.262500
# INFO:root:Epoch[2] Train-multi-accuracy_0=0.155134
# INFO:root:Epoch[2] Train-multi-accuracy_1=0.008929
# INFO:root:Epoch[2] Train-multi-accuracy_2=0.232143
# INFO:root:Epoch[2] Time cost=108.611
# INFO:root:Epoch[2] Validation-multi-accuracy_0=0.185096
# INFO:root:Epoch[2] Validation-multi-accuracy_1=0.010417
# INFO:root:Epoch[2] Validation-multi-accuracy_2=0.301282
# INFO:root:Epoch[3] Batch [20]	Speed: 458.16 samples/sec	Train-multi-accuracy_0=0.158482
# INFO:root:Epoch[3] Batch [20]	Speed: 458.16 samples/sec	Train-multi-accuracy_1=0.011161
# INFO:root:Epoch[3] Batch [20]	Speed: 458.16 samples/sec	Train-multi-accuracy_2=0.321429
# INFO:root:Epoch[3] Batch [40]	Speed: 457.83 samples/sec	Train-multi-accuracy_0=0.166797
# INFO:root:Epoch[3] Batch [40]	Speed: 457.83 samples/sec	Train-multi-accuracy_1=0.011328
# INFO:root:Epoch[3] Batch [40]	Speed: 457.83 samples/sec	Train-multi-accuracy_2=0.312500
# INFO:root:Epoch[3] Batch [60]	Speed: 457.91 samples/sec	Train-multi-accuracy_0=0.178906
# INFO:root:Epoch[3] Batch [60]	Speed: 457.91 samples/sec	Train-multi-accuracy_1=0.011328
# INFO:root:Epoch[3] Batch [60]	Speed: 457.91 samples/sec	Train-multi-accuracy_2=0.325000
# INFO:root:Epoch[3] Batch [80]	Speed: 458.48 samples/sec	Train-multi-accuracy_0=0.175391
# INFO:root:Epoch[3] Batch [80]	Speed: 458.48 samples/sec	Train-multi-accuracy_1=0.010156
# INFO:root:Epoch[3] Batch [80]	Speed: 458.48 samples/sec	Train-multi-accuracy_2=0.362500
# INFO:root:Epoch[3] Batch [100]	Speed: 458.20 samples/sec	Train-multi-accuracy_0=0.192188
# INFO:root:Epoch[3] Batch [100]	Speed: 458.20 samples/sec	Train-multi-accuracy_1=0.012109
# INFO:root:Epoch[3] Batch [100]	Speed: 458.20 samples/sec	Train-multi-accuracy_2=0.275000
# INFO:root:Epoch[3] Batch [120]	Speed: 457.31 samples/sec	Train-multi-accuracy_0=0.178125
# INFO:root:Epoch[3] Batch [120]	Speed: 457.31 samples/sec	Train-multi-accuracy_1=0.007031
# INFO:root:Epoch[3] Batch [120]	Speed: 457.31 samples/sec	Train-multi-accuracy_2=0.362500
# INFO:root:Epoch[3] Batch [140]	Speed: 457.71 samples/sec	Train-multi-accuracy_0=0.192578
# INFO:root:Epoch[3] Batch [140]	Speed: 457.71 samples/sec	Train-multi-accuracy_1=0.007812
# INFO:root:Epoch[3] Batch [140]	Speed: 457.71 samples/sec	Train-multi-accuracy_2=0.337500
# INFO:root:Epoch[3] Batch [160]	Speed: 457.43 samples/sec	Train-multi-accuracy_0=0.184375
# INFO:root:Epoch[3] Batch [160]	Speed: 457.43 samples/sec	Train-multi-accuracy_1=0.008594
# INFO:root:Epoch[3] Batch [160]	Speed: 457.43 samples/sec	Train-multi-accuracy_2=0.375000
# INFO:root:Epoch[3] Batch [180]	Speed: 458.10 samples/sec	Train-multi-accuracy_0=0.186328
# INFO:root:Epoch[3] Batch [180]	Speed: 458.10 samples/sec	Train-multi-accuracy_1=0.010937
# INFO:root:Epoch[3] Batch [180]	Speed: 458.10 samples/sec	Train-multi-accuracy_2=0.400000
# INFO:root:Epoch[3] Train-multi-accuracy_0=0.191667
# INFO:root:Epoch[3] Train-multi-accuracy_1=0.009896
# INFO:root:Epoch[3] Train-multi-accuracy_2=0.400000
# INFO:root:Epoch[3] Time cost=109.249
# INFO:root:Epoch[3] Validation-multi-accuracy_0=0.252404
# INFO:root:Epoch[3] Validation-multi-accuracy_1=0.010617
# INFO:root:Epoch[3] Validation-multi-accuracy_2=0.294872
# INFO:root:Epoch[4] Batch [20]	Speed: 457.89 samples/sec	Train-multi-accuracy_0=0.200893
# INFO:root:Epoch[4] Batch [20]	Speed: 457.89 samples/sec	Train-multi-accuracy_1=0.010045
# INFO:root:Epoch[4] Batch [20]	Speed: 457.89 samples/sec	Train-multi-accuracy_2=0.333333
# INFO:root:Epoch[4] Batch [40]	Speed: 458.11 samples/sec	Train-multi-accuracy_0=0.195703
# INFO:root:Epoch[4] Batch [40]	Speed: 458.11 samples/sec	Train-multi-accuracy_1=0.010547
# INFO:root:Epoch[4] Batch [40]	Speed: 458.11 samples/sec	Train-multi-accuracy_2=0.300000
# INFO:root:Epoch[4] Batch [60]	Speed: 458.15 samples/sec	Train-multi-accuracy_0=0.230859
# INFO:root:Epoch[4] Batch [60]	Speed: 458.15 samples/sec	Train-multi-accuracy_1=0.006250
# INFO:root:Epoch[4] Batch [60]	Speed: 458.15 samples/sec	Train-multi-accuracy_2=0.312500
# INFO:root:Epoch[4] Batch [80]	Speed: 458.15 samples/sec	Train-multi-accuracy_0=0.207813
# INFO:root:Epoch[4] Batch [80]	Speed: 458.15 samples/sec	Train-multi-accuracy_1=0.010547
# INFO:root:Epoch[4] Batch [80]	Speed: 458.15 samples/sec	Train-multi-accuracy_2=0.312500
# INFO:root:Epoch[4] Batch [100]	Speed: 457.93 samples/sec	Train-multi-accuracy_0=0.206641
# INFO:root:Epoch[4] Batch [100]	Speed: 457.93 samples/sec	Train-multi-accuracy_1=0.013672
# INFO:root:Epoch[4] Batch [100]	Speed: 457.93 samples/sec	Train-multi-accuracy_2=0.287500
# INFO:root:Epoch[4] Batch [120]	Speed: 458.15 samples/sec	Train-multi-accuracy_0=0.227344
# INFO:root:Epoch[4] Batch [120]	Speed: 458.15 samples/sec	Train-multi-accuracy_1=0.007422
# INFO:root:Epoch[4] Batch [120]	Speed: 458.15 samples/sec	Train-multi-accuracy_2=0.387500
# INFO:root:Epoch[4] Batch [140]	Speed: 458.08 samples/sec	Train-multi-accuracy_0=0.225000
# INFO:root:Epoch[4] Batch [140]	Speed: 458.08 samples/sec	Train-multi-accuracy_1=0.010547
# INFO:root:Epoch[4] Batch [140]	Speed: 458.08 samples/sec	Train-multi-accuracy_2=0.412500
# INFO:root:Epoch[4] Batch [160]	Speed: 458.35 samples/sec	Train-multi-accuracy_0=0.228516
# INFO:root:Epoch[4] Batch [160]	Speed: 458.35 samples/sec	Train-multi-accuracy_1=0.009766
# INFO:root:Epoch[4] Batch [160]	Speed: 458.35 samples/sec	Train-multi-accuracy_2=0.387500
# INFO:root:Epoch[4] Batch [180]	Speed: 458.13 samples/sec	Train-multi-accuracy_0=0.233594
# INFO:root:Epoch[4] Batch [180]	Speed: 458.13 samples/sec	Train-multi-accuracy_1=0.011719
# INFO:root:Epoch[4] Batch [180]	Speed: 458.13 samples/sec	Train-multi-accuracy_2=0.300000
# INFO:root:Epoch[4] Train-multi-accuracy_0=0.234375
# INFO:root:Epoch[4] Train-multi-accuracy_1=0.011719
# INFO:root:Epoch[4] Train-multi-accuracy_2=0.303571
# INFO:root:Epoch[4] Time cost=108.634
# INFO:root:Epoch[4] Validation-multi-accuracy_0=0.277043
# INFO:root:Epoch[4] Validation-multi-accuracy_1=0.009014
# INFO:root:Epoch[4] Validation-multi-accuracy_2=0.307692
# INFO:root:Epoch[5] Batch [20]	Speed: 458.13 samples/sec	Train-multi-accuracy_0=0.247396
# INFO:root:Epoch[5] Batch [20]	Speed: 458.13 samples/sec	Train-multi-accuracy_1=0.011905
# INFO:root:Epoch[5] Batch [20]	Speed: 458.13 samples/sec	Train-multi-accuracy_2=0.273810
# INFO:root:Batch:    1001 loss_aba_backward_data         0.0763634
# INFO:root:Batch:    1001 loss_aba_backward_label        0.0759954
# INFO:root:Batch:    1001 p_aba_backward_0               0.0746465
# INFO:root:Batch:    1001 p_aba_backward_1               0.0700371
# INFO:root:Batch:    1001 loss_aba_backward_data         0.0780319
# INFO:root:Batch:    1001 loss_aba_backward_label        0.0718017
# INFO:root:Batch:    1001 p_aba_backward_0               0.0751105
# INFO:root:Batch:    1001 p_aba_backward_1               0.0734697
# INFO:root:Batch:    1001 loss_aba_backward_data         0.0795822
# INFO:root:Batch:    1001 loss_aba_backward_label        0.070874
# INFO:root:Batch:    1001 p_aba_backward_0               0.0744426
# INFO:root:Batch:    1001 p_aba_backward_1               0.0728875
# INFO:root:Batch:    1001 loss_aba_backward_data         0.0747585
# INFO:root:Batch:    1001 loss_aba_backward_label        0.0687626
# INFO:root:Batch:    1001 p_aba_backward_0               0.0724861
# INFO:root:Batch:    1001 p_aba_backward_1               0.0689168
# INFO:root:Epoch[5] Batch [40]	Speed: 457.29 samples/sec	Train-multi-accuracy_0=0.232422
# INFO:root:Epoch[5] Batch [40]	Speed: 457.29 samples/sec	Train-multi-accuracy_1=0.007812
# INFO:root:Epoch[5] Batch [40]	Speed: 457.29 samples/sec	Train-multi-accuracy_2=0.362500
# INFO:root:Epoch[5] Batch [60]	Speed: 458.50 samples/sec	Train-multi-accuracy_0=0.257031
# INFO:root:Epoch[5] Batch [60]	Speed: 458.50 samples/sec	Train-multi-accuracy_1=0.014063
# INFO:root:Epoch[5] Batch [60]	Speed: 458.50 samples/sec	Train-multi-accuracy_2=0.325000
# INFO:root:Epoch[5] Batch [80]	Speed: 458.29 samples/sec	Train-multi-accuracy_0=0.261719
# INFO:root:Epoch[5] Batch [80]	Speed: 458.29 samples/sec	Train-multi-accuracy_1=0.010937
# INFO:root:Epoch[5] Batch [80]	Speed: 458.29 samples/sec	Train-multi-accuracy_2=0.312500
# INFO:root:Epoch[5] Batch [100]	Speed: 458.20 samples/sec	Train-multi-accuracy_0=0.241016
# INFO:root:Epoch[5] Batch [100]	Speed: 458.20 samples/sec	Train-multi-accuracy_1=0.011328
# INFO:root:Epoch[5] Batch [100]	Speed: 458.20 samples/sec	Train-multi-accuracy_2=0.362500
# INFO:root:Epoch[5] Batch [120]	Speed: 458.39 samples/sec	Train-multi-accuracy_0=0.254297
# INFO:root:Epoch[5] Batch [120]	Speed: 458.39 samples/sec	Train-multi-accuracy_1=0.007812
# INFO:root:Epoch[5] Batch [120]	Speed: 458.39 samples/sec	Train-multi-accuracy_2=0.275000
# INFO:root:Epoch[5] Batch [140]	Speed: 458.40 samples/sec	Train-multi-accuracy_0=0.247266
# INFO:root:Epoch[5] Batch [140]	Speed: 458.40 samples/sec	Train-multi-accuracy_1=0.005078
# INFO:root:Epoch[5] Batch [140]	Speed: 458.40 samples/sec	Train-multi-accuracy_2=0.450000
# INFO:root:Epoch[5] Batch [160]	Speed: 458.10 samples/sec	Train-multi-accuracy_0=0.249219
# INFO:root:Epoch[5] Batch [160]	Speed: 458.10 samples/sec	Train-multi-accuracy_1=0.009375
# INFO:root:Epoch[5] Batch [160]	Speed: 458.10 samples/sec	Train-multi-accuracy_2=0.262500
# INFO:root:Epoch[5] Batch [180]	Speed: 458.15 samples/sec	Train-multi-accuracy_0=0.270313
# INFO:root:Epoch[5] Batch [180]	Speed: 458.15 samples/sec	Train-multi-accuracy_1=0.007422
# INFO:root:Epoch[5] Batch [180]	Speed: 458.15 samples/sec	Train-multi-accuracy_2=0.512500
# INFO:root:Epoch[5] Train-multi-accuracy_0=0.270089
# INFO:root:Epoch[5] Train-multi-accuracy_1=0.011161
# INFO:root:Epoch[5] Train-multi-accuracy_2=0.321429
# INFO:root:Epoch[5] Time cost=108.627
# INFO:root:Epoch[5] Validation-multi-accuracy_0=0.293870
# INFO:root:Epoch[5] Validation-multi-accuracy_1=0.009014
# INFO:root:Epoch[5] Validation-multi-accuracy_2=0.346154
# INFO:root:Epoch[6] Batch [20]	Speed: 457.71 samples/sec	Train-multi-accuracy_0=0.279762
# INFO:root:Epoch[6] Batch [20]	Speed: 457.71 samples/sec	Train-multi-accuracy_1=0.006324
# INFO:root:Epoch[6] Batch [20]	Speed: 457.71 samples/sec	Train-multi-accuracy_2=0.333333
# INFO:root:Epoch[6] Batch [40]	Speed: 457.95 samples/sec	Train-multi-accuracy_0=0.283984
# INFO:root:Epoch[6] Batch [40]	Speed: 457.95 samples/sec	Train-multi-accuracy_1=0.014844
# INFO:root:Epoch[6] Batch [40]	Speed: 457.95 samples/sec	Train-multi-accuracy_2=0.425000
# INFO:root:Epoch[6] Batch [60]	Speed: 458.75 samples/sec	Train-multi-accuracy_0=0.274219
# INFO:root:Epoch[6] Batch [60]	Speed: 458.75 samples/sec	Train-multi-accuracy_1=0.010547
# INFO:root:Epoch[6] Batch [60]	Speed: 458.75 samples/sec	Train-multi-accuracy_2=0.362500
# INFO:root:Epoch[6] Batch [80]	Speed: 457.66 samples/sec	Train-multi-accuracy_0=0.280078
# INFO:root:Epoch[6] Batch [80]	Speed: 457.66 samples/sec	Train-multi-accuracy_1=0.007031
# INFO:root:Epoch[6] Batch [80]	Speed: 457.66 samples/sec	Train-multi-accuracy_2=0.312500
# INFO:root:Epoch[6] Batch [100]	Speed: 458.43 samples/sec	Train-multi-accuracy_0=0.274219
# INFO:root:Epoch[6] Batch [100]	Speed: 458.43 samples/sec	Train-multi-accuracy_1=0.008594
# INFO:root:Epoch[6] Batch [100]	Speed: 458.43 samples/sec	Train-multi-accuracy_2=0.437500
# INFO:root:Epoch[6] Batch [120]	Speed: 458.34 samples/sec	Train-multi-accuracy_0=0.282422
# INFO:root:Epoch[6] Batch [120]	Speed: 458.34 samples/sec	Train-multi-accuracy_1=0.008984
# INFO:root:Epoch[6] Batch [120]	Speed: 458.34 samples/sec	Train-multi-accuracy_2=0.300000
# INFO:root:Epoch[6] Batch [140]	Speed: 458.30 samples/sec	Train-multi-accuracy_0=0.301953
# INFO:root:Epoch[6] Batch [140]	Speed: 458.30 samples/sec	Train-multi-accuracy_1=0.007812
# INFO:root:Epoch[6] Batch [140]	Speed: 458.30 samples/sec	Train-multi-accuracy_2=0.250000
# INFO:root:Epoch[6] Batch [160]	Speed: 458.08 samples/sec	Train-multi-accuracy_0=0.286328
# INFO:root:Epoch[6] Batch [160]	Speed: 458.08 samples/sec	Train-multi-accuracy_1=0.009375
# INFO:root:Epoch[6] Batch [160]	Speed: 458.08 samples/sec	Train-multi-accuracy_2=0.300000
# INFO:root:Epoch[6] Batch [180]	Speed: 458.12 samples/sec	Train-multi-accuracy_0=0.297266
# INFO:root:Epoch[6] Batch [180]	Speed: 458.12 samples/sec	Train-multi-accuracy_1=0.013281
# INFO:root:Epoch[6] Batch [180]	Speed: 458.12 samples/sec	Train-multi-accuracy_2=0.300000
# INFO:root:Epoch[6] Train-multi-accuracy_0=0.283854
# INFO:root:Epoch[6] Train-multi-accuracy_1=0.008854
# INFO:root:Epoch[6] Train-multi-accuracy_2=0.233333
# INFO:root:Epoch[6] Time cost=109.188
# INFO:root:Epoch[6] Validation-multi-accuracy_0=0.333333
# INFO:root:Epoch[6] Validation-multi-accuracy_1=0.010016
# INFO:root:Epoch[6] Validation-multi-accuracy_2=0.288462
# INFO:root:Epoch[7] Batch [20]	Speed: 457.93 samples/sec	Train-multi-accuracy_0=0.287202
# INFO:root:Epoch[7] Batch [20]	Speed: 457.93 samples/sec	Train-multi-accuracy_1=0.010045
# INFO:root:Epoch[7] Batch [20]	Speed: 457.93 samples/sec	Train-multi-accuracy_2=0.357143
# INFO:root:Epoch[7] Batch [40]	Speed: 457.72 samples/sec	Train-multi-accuracy_0=0.299219
# INFO:root:Epoch[7] Batch [40]	Speed: 457.72 samples/sec	Train-multi-accuracy_1=0.008984
# INFO:root:Epoch[7] Batch [40]	Speed: 457.72 samples/sec	Train-multi-accuracy_2=0.400000
# INFO:root:Epoch[7] Batch [60]	Speed: 458.02 samples/sec	Train-multi-accuracy_0=0.306250
# INFO:root:Epoch[7] Batch [60]	Speed: 458.02 samples/sec	Train-multi-accuracy_1=0.010547
# INFO:root:Epoch[7] Batch [60]	Speed: 458.02 samples/sec	Train-multi-accuracy_2=0.275000
# INFO:root:Epoch[7] Batch [80]	Speed: 457.10 samples/sec	Train-multi-accuracy_0=0.308984
# INFO:root:Epoch[7] Batch [80]	Speed: 457.10 samples/sec	Train-multi-accuracy_1=0.007422
# INFO:root:Epoch[7] Batch [80]	Speed: 457.10 samples/sec	Train-multi-accuracy_2=0.400000
# INFO:root:Epoch[7] Batch [100]	Speed: 458.03 samples/sec	Train-multi-accuracy_0=0.303125
# INFO:root:Epoch[7] Batch [100]	Speed: 458.03 samples/sec	Train-multi-accuracy_1=0.008594
# INFO:root:Epoch[7] Batch [100]	Speed: 458.03 samples/sec	Train-multi-accuracy_2=0.325000
# INFO:root:Epoch[7] Batch [120]	Speed: 457.89 samples/sec	Train-multi-accuracy_0=0.320312
# INFO:root:Epoch[7] Batch [120]	Speed: 457.89 samples/sec	Train-multi-accuracy_1=0.010156
# INFO:root:Epoch[7] Batch [120]	Speed: 457.89 samples/sec	Train-multi-accuracy_2=0.375000
# INFO:root:Epoch[7] Batch [140]	Speed: 457.43 samples/sec	Train-multi-accuracy_0=0.320312
# INFO:root:Epoch[7] Batch [140]	Speed: 457.43 samples/sec	Train-multi-accuracy_1=0.009766
# INFO:root:Epoch[7] Batch [140]	Speed: 457.43 samples/sec	Train-multi-accuracy_2=0.300000
# INFO:root:Epoch[7] Batch [160]	Speed: 458.08 samples/sec	Train-multi-accuracy_0=0.325000
# INFO:root:Epoch[7] Batch [160]	Speed: 458.08 samples/sec	Train-multi-accuracy_1=0.010156
# INFO:root:Epoch[7] Batch [160]	Speed: 458.08 samples/sec	Train-multi-accuracy_2=0.250000
# INFO:root:Epoch[7] Batch [180]	Speed: 458.15 samples/sec	Train-multi-accuracy_0=0.325391
# INFO:root:Epoch[7] Batch [180]	Speed: 458.15 samples/sec	Train-multi-accuracy_1=0.011328
# INFO:root:Epoch[7] Batch [180]	Speed: 458.15 samples/sec	Train-multi-accuracy_2=0.350000
# INFO:root:Epoch[7] Train-multi-accuracy_0=0.319754
# INFO:root:Epoch[7] Train-multi-accuracy_1=0.008371
# INFO:root:Epoch[7] Train-multi-accuracy_2=0.125000
# INFO:root:Epoch[7] Time cost=108.706
# INFO:root:Epoch[7] Validation-multi-accuracy_0=0.369992
# INFO:root:Epoch[7] Validation-multi-accuracy_1=0.011218
# INFO:root:Epoch[7] Validation-multi-accuracy_2=0.314103
# INFO:root:Epoch[8] Batch [20]	Speed: 457.65 samples/sec	Train-multi-accuracy_0=0.342634
# INFO:root:Epoch[8] Batch [20]	Speed: 457.65 samples/sec	Train-multi-accuracy_1=0.011161
# INFO:root:Epoch[8] Batch [20]	Speed: 457.65 samples/sec	Train-multi-accuracy_2=0.345238
# INFO:root:Epoch[8] Batch [40]	Speed: 458.52 samples/sec	Train-multi-accuracy_0=0.354687
# INFO:root:Epoch[8] Batch [40]	Speed: 458.52 samples/sec	Train-multi-accuracy_1=0.008984
# INFO:root:Epoch[8] Batch [40]	Speed: 458.52 samples/sec	Train-multi-accuracy_2=0.337500
# INFO:root:Epoch[8] Batch [60]	Speed: 458.18 samples/sec	Train-multi-accuracy_0=0.353516
# INFO:root:Epoch[8] Batch [60]	Speed: 458.18 samples/sec	Train-multi-accuracy_1=0.011328
# INFO:root:Epoch[8] Batch [60]	Speed: 458.18 samples/sec	Train-multi-accuracy_2=0.237500
# INFO:root:Epoch[8] Batch [80]	Speed: 457.91 samples/sec	Train-multi-accuracy_0=0.347266
# INFO:root:Epoch[8] Batch [80]	Speed: 457.91 samples/sec	Train-multi-accuracy_1=0.010547
# INFO:root:Epoch[8] Batch [80]	Speed: 457.91 samples/sec	Train-multi-accuracy_2=0.387500
# INFO:root:Epoch[8] Batch [100]	Speed: 458.17 samples/sec	Train-multi-accuracy_0=0.344922
# INFO:root:Epoch[8] Batch [100]	Speed: 458.17 samples/sec	Train-multi-accuracy_1=0.008594
# INFO:root:Epoch[8] Batch [100]	Speed: 458.17 samples/sec	Train-multi-accuracy_2=0.287500
# INFO:root:Epoch[8] Batch [120]	Speed: 457.91 samples/sec	Train-multi-accuracy_0=0.354297
# INFO:root:Epoch[8] Batch [120]	Speed: 457.91 samples/sec	Train-multi-accuracy_1=0.010156
# INFO:root:Epoch[8] Batch [120]	Speed: 457.91 samples/sec	Train-multi-accuracy_2=0.337500
# INFO:root:Epoch[8] Batch [140]	Speed: 458.66 samples/sec	Train-multi-accuracy_0=0.344531
# INFO:root:Epoch[8] Batch [140]	Speed: 458.66 samples/sec	Train-multi-accuracy_1=0.012891
# INFO:root:Epoch[8] Batch [140]	Speed: 458.66 samples/sec	Train-multi-accuracy_2=0.187500
# INFO:root:Epoch[8] Batch [160]	Speed: 458.10 samples/sec	Train-multi-accuracy_0=0.351953
# INFO:root:Epoch[8] Batch [160]	Speed: 458.10 samples/sec	Train-multi-accuracy_1=0.008594
# INFO:root:Epoch[8] Batch [160]	Speed: 458.10 samples/sec	Train-multi-accuracy_2=0.337500
# INFO:root:Epoch[8] Batch [180]	Speed: 458.11 samples/sec	Train-multi-accuracy_0=0.366016
# INFO:root:Epoch[8] Batch [180]	Speed: 458.11 samples/sec	Train-multi-accuracy_1=0.012891
# INFO:root:Epoch[8] Batch [180]	Speed: 458.11 samples/sec	Train-multi-accuracy_2=0.337500
# INFO:root:Epoch[8] Train-multi-accuracy_0=0.361607
# INFO:root:Epoch[8] Train-multi-accuracy_1=0.009487
# INFO:root:Epoch[8] Train-multi-accuracy_2=0.339286
# INFO:root:Epoch[8] Time cost=108.629
# INFO:root:Epoch[8] Validation-multi-accuracy_0=0.387420
# INFO:root:Epoch[8] Validation-multi-accuracy_1=0.008213
# INFO:root:Epoch[8] Validation-multi-accuracy_2=0.256410
# INFO:root:Epoch[9] Batch [20]	Speed: 457.89 samples/sec	Train-multi-accuracy_0=0.357887
# INFO:root:Epoch[9] Batch [20]	Speed: 457.89 samples/sec	Train-multi-accuracy_1=0.010045
# INFO:root:Epoch[9] Batch [20]	Speed: 457.89 samples/sec	Train-multi-accuracy_2=0.345238
# INFO:root:Epoch[9] Batch [40]	Speed: 457.75 samples/sec	Train-multi-accuracy_0=0.360156
# INFO:root:Epoch[9] Batch [40]	Speed: 457.75 samples/sec	Train-multi-accuracy_1=0.008984
# INFO:root:Epoch[9] Batch [40]	Speed: 457.75 samples/sec	Train-multi-accuracy_2=0.312500
# INFO:root:Epoch[9] Batch [60]	Speed: 458.01 samples/sec	Train-multi-accuracy_0=0.363672
# INFO:root:Epoch[9] Batch [60]	Speed: 458.01 samples/sec	Train-multi-accuracy_1=0.010156
# INFO:root:Epoch[9] Batch [60]	Speed: 458.01 samples/sec	Train-multi-accuracy_2=0.300000
# INFO:root:Epoch[9] Batch [80]	Speed: 458.14 samples/sec	Train-multi-accuracy_0=0.358984
# INFO:root:Epoch[9] Batch [80]	Speed: 458.14 samples/sec	Train-multi-accuracy_1=0.013672
# INFO:root:Epoch[9] Batch [80]	Speed: 458.14 samples/sec	Train-multi-accuracy_2=0.275000
# INFO:root:Epoch[9] Batch [100]	Speed: 457.35 samples/sec	Train-multi-accuracy_0=0.372266
# INFO:root:Epoch[9] Batch [100]	Speed: 457.35 samples/sec	Train-multi-accuracy_1=0.008203
# INFO:root:Epoch[9] Batch [100]	Speed: 457.35 samples/sec	Train-multi-accuracy_2=0.400000
# INFO:root:Epoch[9] Batch [120]	Speed: 457.99 samples/sec	Train-multi-accuracy_0=0.373437
# INFO:root:Epoch[9] Batch [120]	Speed: 457.99 samples/sec	Train-multi-accuracy_1=0.006250
# INFO:root:Epoch[9] Batch [120]	Speed: 457.99 samples/sec	Train-multi-accuracy_2=0.225000
# INFO:root:Epoch[9] Batch [140]	Speed: 458.24 samples/sec	Train-multi-accuracy_0=0.362891
# INFO:root:Epoch[9] Batch [140]	Speed: 458.24 samples/sec	Train-multi-accuracy_1=0.012109
# INFO:root:Epoch[9] Batch [140]	Speed: 458.24 samples/sec	Train-multi-accuracy_2=0.275000
# INFO:root:Epoch[9] Batch [160]	Speed: 457.53 samples/sec	Train-multi-accuracy_0=0.371484
# INFO:root:Epoch[9] Batch [160]	Speed: 457.53 samples/sec	Train-multi-accuracy_1=0.009375
# INFO:root:Epoch[9] Batch [160]	Speed: 457.53 samples/sec	Train-multi-accuracy_2=0.287500
# INFO:root:Epoch[9] Batch [180]	Speed: 457.98 samples/sec	Train-multi-accuracy_0=0.378516
# INFO:root:Epoch[9] Batch [180]	Speed: 457.98 samples/sec	Train-multi-accuracy_1=0.014453
# INFO:root:Epoch[9] Batch [180]	Speed: 457.98 samples/sec	Train-multi-accuracy_2=0.400000
# INFO:root:Epoch[9] Train-multi-accuracy_0=0.363021
# INFO:root:Epoch[9] Train-multi-accuracy_1=0.007292
# INFO:root:Epoch[9] Train-multi-accuracy_2=0.250000
# INFO:root:Epoch[9] Time cost=109.255
# INFO:root:Epoch[9] Validation-multi-accuracy_0=0.402244
# INFO:root:Epoch[9] Validation-multi-accuracy_1=0.009615
# INFO:root:Epoch[9] Validation-multi-accuracy_2=0.237179
# INFO:root:Epoch[10] Batch [20]	Speed: 457.24 samples/sec	Train-multi-accuracy_0=0.375372
# INFO:root:Epoch[10] Batch [20]	Speed: 457.24 samples/sec	Train-multi-accuracy_1=0.007812
# INFO:root:Epoch[10] Batch [20]	Speed: 457.24 samples/sec	Train-multi-accuracy_2=0.261905
# INFO:root:Epoch[10] Batch [40]	Speed: 458.05 samples/sec	Train-multi-accuracy_0=0.387891
# INFO:root:Epoch[10] Batch [40]	Speed: 458.05 samples/sec	Train-multi-accuracy_1=0.011328
# INFO:root:Epoch[10] Batch [40]	Speed: 458.05 samples/sec	Train-multi-accuracy_2=0.300000
# INFO:root:Batch:    2001 loss_aba_backward_data         0.082376
# INFO:root:Batch:    2001 loss_aba_backward_label        0.0730449
# INFO:root:Batch:    2001 p_aba_backward_0               0.0763057
# INFO:root:Batch:    2001 p_aba_backward_1               0.072668
# INFO:root:Batch:    2001 loss_aba_backward_data         0.0764437
# INFO:root:Batch:    2001 loss_aba_backward_label        0.0749129
# INFO:root:Batch:    2001 p_aba_backward_0               0.0715151
# INFO:root:Batch:    2001 p_aba_backward_1               0.0688181
# INFO:root:Batch:    2001 loss_aba_backward_data         0.076476
# INFO:root:Batch:    2001 loss_aba_backward_label        0.0786298
# INFO:root:Batch:    2001 p_aba_backward_0               0.0733469
# INFO:root:Batch:    2001 p_aba_backward_1               0.0734324
# INFO:root:Batch:    2001 loss_aba_backward_data         0.0810723
# INFO:root:Batch:    2001 loss_aba_backward_label        0.0769338
# INFO:root:Batch:    2001 p_aba_backward_0               0.0746168
# INFO:root:Batch:    2001 p_aba_backward_1               0.0735159
# INFO:root:Epoch[10] Batch [60]	Speed: 456.71 samples/sec	Train-multi-accuracy_0=0.403125
# INFO:root:Epoch[10] Batch [60]	Speed: 456.71 samples/sec	Train-multi-accuracy_1=0.010156
# INFO:root:Epoch[10] Batch [60]	Speed: 456.71 samples/sec	Train-multi-accuracy_2=0.362500
# INFO:root:Epoch[10] Batch [80]	Speed: 457.85 samples/sec	Train-multi-accuracy_0=0.410156
# INFO:root:Epoch[10] Batch [80]	Speed: 457.85 samples/sec	Train-multi-accuracy_1=0.010937
# INFO:root:Epoch[10] Batch [80]	Speed: 457.85 samples/sec	Train-multi-accuracy_2=0.325000
# INFO:root:Epoch[10] Batch [100]	Speed: 457.59 samples/sec	Train-multi-accuracy_0=0.380859
# INFO:root:Epoch[10] Batch [100]	Speed: 457.59 samples/sec	Train-multi-accuracy_1=0.010547
# INFO:root:Epoch[10] Batch [100]	Speed: 457.59 samples/sec	Train-multi-accuracy_2=0.237500
# INFO:root:Epoch[10] Batch [120]	Speed: 457.66 samples/sec	Train-multi-accuracy_0=0.383594
# INFO:root:Epoch[10] Batch [120]	Speed: 457.66 samples/sec	Train-multi-accuracy_1=0.008984
# INFO:root:Epoch[10] Batch [120]	Speed: 457.66 samples/sec	Train-multi-accuracy_2=0.350000
# INFO:root:Epoch[10] Batch [140]	Speed: 458.61 samples/sec	Train-multi-accuracy_0=0.389062
# INFO:root:Epoch[10] Batch [140]	Speed: 458.61 samples/sec	Train-multi-accuracy_1=0.009766
# INFO:root:Epoch[10] Batch [140]	Speed: 458.61 samples/sec	Train-multi-accuracy_2=0.400000
# INFO:root:Epoch[10] Batch [160]	Speed: 457.97 samples/sec	Train-multi-accuracy_0=0.383984
# INFO:root:Epoch[10] Batch [160]	Speed: 457.97 samples/sec	Train-multi-accuracy_1=0.016016
# INFO:root:Epoch[10] Batch [160]	Speed: 457.97 samples/sec	Train-multi-accuracy_2=0.337500
# INFO:root:Epoch[10] Batch [180]	Speed: 458.16 samples/sec	Train-multi-accuracy_0=0.389844
# INFO:root:Epoch[10] Batch [180]	Speed: 458.16 samples/sec	Train-multi-accuracy_1=0.012500
# INFO:root:Epoch[10] Batch [180]	Speed: 458.16 samples/sec	Train-multi-accuracy_2=0.312500
# INFO:root:Epoch[10] Train-multi-accuracy_0=0.406250
# INFO:root:Epoch[10] Train-multi-accuracy_1=0.011161
# INFO:root:Epoch[10] Train-multi-accuracy_2=0.375000
# INFO:root:Epoch[10] Time cost=108.718
# INFO:root:Epoch[10] Validation-multi-accuracy_0=0.432692
# INFO:root:Epoch[10] Validation-multi-accuracy_1=0.009615
# INFO:root:Epoch[10] Validation-multi-accuracy_2=0.326923
# INFO:root:Epoch[11] Batch [20]	Speed: 457.38 samples/sec	Train-multi-accuracy_0=0.406994
# INFO:root:Epoch[11] Batch [20]	Speed: 457.38 samples/sec	Train-multi-accuracy_1=0.010417
# INFO:root:Epoch[11] Batch [20]	Speed: 457.38 samples/sec	Train-multi-accuracy_2=0.250000
# INFO:root:Epoch[11] Batch [40]	Speed: 458.02 samples/sec	Train-multi-accuracy_0=0.424219
# INFO:root:Epoch[11] Batch [40]	Speed: 458.02 samples/sec	Train-multi-accuracy_1=0.012109
# INFO:root:Epoch[11] Batch [40]	Speed: 458.02 samples/sec	Train-multi-accuracy_2=0.225000
# INFO:root:Epoch[11] Batch [60]	Speed: 457.85 samples/sec	Train-multi-accuracy_0=0.421094
# INFO:root:Epoch[11] Batch [60]	Speed: 457.85 samples/sec	Train-multi-accuracy_1=0.015625
# INFO:root:Epoch[11] Batch [60]	Speed: 457.85 samples/sec	Train-multi-accuracy_2=0.300000
# INFO:root:Epoch[11] Batch [80]	Speed: 457.89 samples/sec	Train-multi-accuracy_0=0.421484
# INFO:root:Epoch[11] Batch [80]	Speed: 457.89 samples/sec	Train-multi-accuracy_1=0.008203
# INFO:root:Epoch[11] Batch [80]	Speed: 457.89 samples/sec	Train-multi-accuracy_2=0.325000
# INFO:root:Epoch[11] Batch [100]	Speed: 458.16 samples/sec	Train-multi-accuracy_0=0.420703
# INFO:root:Epoch[11] Batch [100]	Speed: 458.16 samples/sec	Train-multi-accuracy_1=0.005469
# INFO:root:Epoch[11] Batch [100]	Speed: 458.16 samples/sec	Train-multi-accuracy_2=0.425000
# INFO:root:Epoch[11] Batch [120]	Speed: 457.65 samples/sec	Train-multi-accuracy_0=0.406641
# INFO:root:Epoch[11] Batch [120]	Speed: 457.65 samples/sec	Train-multi-accuracy_1=0.007812
# INFO:root:Epoch[11] Batch [120]	Speed: 457.65 samples/sec	Train-multi-accuracy_2=0.325000
# INFO:root:Epoch[11] Batch [140]	Speed: 457.30 samples/sec	Train-multi-accuracy_0=0.424219
# INFO:root:Epoch[11] Batch [140]	Speed: 457.30 samples/sec	Train-multi-accuracy_1=0.008594
# INFO:root:Epoch[11] Batch [140]	Speed: 457.30 samples/sec	Train-multi-accuracy_2=0.212500
# INFO:root:Epoch[11] Batch [160]	Speed: 457.99 samples/sec	Train-multi-accuracy_0=0.428516
# INFO:root:Epoch[11] Batch [160]	Speed: 457.99 samples/sec	Train-multi-accuracy_1=0.008203
# INFO:root:Epoch[11] Batch [160]	Speed: 457.99 samples/sec	Train-multi-accuracy_2=0.300000
# INFO:root:Epoch[11] Batch [180]	Speed: 458.34 samples/sec	Train-multi-accuracy_0=0.431641
# INFO:root:Epoch[11] Batch [180]	Speed: 458.34 samples/sec	Train-multi-accuracy_1=0.005469
# INFO:root:Epoch[11] Batch [180]	Speed: 458.34 samples/sec	Train-multi-accuracy_2=0.250000
# INFO:root:Epoch[11] Train-multi-accuracy_0=0.414062
# INFO:root:Epoch[11] Train-multi-accuracy_1=0.007254
# INFO:root:Epoch[11] Train-multi-accuracy_2=0.339286
# INFO:root:Epoch[11] Time cost=108.698
# INFO:root:Epoch[11] Validation-multi-accuracy_0=0.449720
# INFO:root:Epoch[11] Validation-multi-accuracy_1=0.012019
# INFO:root:Epoch[11] Validation-multi-accuracy_2=0.346154
# INFO:root:Epoch[12] Batch [20]	Speed: 457.98 samples/sec	Train-multi-accuracy_0=0.428199
# INFO:root:Epoch[12] Batch [20]	Speed: 457.98 samples/sec	Train-multi-accuracy_1=0.007812
# INFO:root:Epoch[12] Batch [20]	Speed: 457.98 samples/sec	Train-multi-accuracy_2=0.369048
# INFO:root:Epoch[12] Batch [40]	Speed: 457.94 samples/sec	Train-multi-accuracy_0=0.421094
# INFO:root:Epoch[12] Batch [40]	Speed: 457.94 samples/sec	Train-multi-accuracy_1=0.012109
# INFO:root:Epoch[12] Batch [40]	Speed: 457.94 samples/sec	Train-multi-accuracy_2=0.250000
# INFO:root:Epoch[12] Batch [60]	Speed: 457.92 samples/sec	Train-multi-accuracy_0=0.432422
# INFO:root:Epoch[12] Batch [60]	Speed: 457.92 samples/sec	Train-multi-accuracy_1=0.008594
# INFO:root:Epoch[12] Batch [60]	Speed: 457.92 samples/sec	Train-multi-accuracy_2=0.375000
# INFO:root:Epoch[12] Batch [80]	Speed: 458.35 samples/sec	Train-multi-accuracy_0=0.436328
# INFO:root:Epoch[12] Batch [80]	Speed: 458.35 samples/sec	Train-multi-accuracy_1=0.010156
# INFO:root:Epoch[12] Batch [80]	Speed: 458.35 samples/sec	Train-multi-accuracy_2=0.400000
# INFO:root:Epoch[12] Batch [100]	Speed: 457.61 samples/sec	Train-multi-accuracy_0=0.437891
# INFO:root:Epoch[12] Batch [100]	Speed: 457.61 samples/sec	Train-multi-accuracy_1=0.008203
# INFO:root:Epoch[12] Batch [100]	Speed: 457.61 samples/sec	Train-multi-accuracy_2=0.325000
# INFO:root:Epoch[12] Batch [120]	Speed: 457.44 samples/sec	Train-multi-accuracy_0=0.435156
# INFO:root:Epoch[12] Batch [120]	Speed: 457.44 samples/sec	Train-multi-accuracy_1=0.007812
# INFO:root:Epoch[12] Batch [120]	Speed: 457.44 samples/sec	Train-multi-accuracy_2=0.262500
# INFO:root:Epoch[12] Batch [140]	Speed: 457.49 samples/sec	Train-multi-accuracy_0=0.455859
# INFO:root:Epoch[12] Batch [140]	Speed: 457.49 samples/sec	Train-multi-accuracy_1=0.009766
# INFO:root:Epoch[12] Batch [140]	Speed: 457.49 samples/sec	Train-multi-accuracy_2=0.375000
# INFO:root:Epoch[12] Batch [160]	Speed: 457.59 samples/sec	Train-multi-accuracy_0=0.430078
# INFO:root:Epoch[12] Batch [160]	Speed: 457.59 samples/sec	Train-multi-accuracy_1=0.010547
# INFO:root:Epoch[12] Batch [160]	Speed: 457.59 samples/sec	Train-multi-accuracy_2=0.312500
# INFO:root:Epoch[12] Batch [180]	Speed: 457.62 samples/sec	Train-multi-accuracy_0=0.454297
# INFO:root:Epoch[12] Batch [180]	Speed: 457.62 samples/sec	Train-multi-accuracy_1=0.010156
# INFO:root:Epoch[12] Batch [180]	Speed: 457.62 samples/sec	Train-multi-accuracy_2=0.287500
# INFO:root:Epoch[12] Train-multi-accuracy_0=0.421354
# INFO:root:Epoch[12] Train-multi-accuracy_1=0.008333
# INFO:root:Epoch[12] Train-multi-accuracy_2=0.316667
# INFO:root:Epoch[12] Time cost=109.265
# INFO:root:Epoch[12] Validation-multi-accuracy_0=0.448317
# INFO:root:Epoch[12] Validation-multi-accuracy_1=0.008814
# INFO:root:Epoch[12] Validation-multi-accuracy_2=0.288462
# INFO:root:Epoch[13] Batch [20]	Speed: 457.49 samples/sec	Train-multi-accuracy_0=0.423735
# INFO:root:Epoch[13] Batch [20]	Speed: 457.49 samples/sec	Train-multi-accuracy_1=0.010045
# INFO:root:Epoch[13] Batch [20]	Speed: 457.49 samples/sec	Train-multi-accuracy_2=0.428571
# INFO:root:Epoch[13] Batch [40]	Speed: 457.94 samples/sec	Train-multi-accuracy_0=0.442188
# INFO:root:Epoch[13] Batch [40]	Speed: 457.94 samples/sec	Train-multi-accuracy_1=0.009766
# INFO:root:Epoch[13] Batch [40]	Speed: 457.94 samples/sec	Train-multi-accuracy_2=0.550000
# INFO:root:Epoch[13] Batch [60]	Speed: 458.16 samples/sec	Train-multi-accuracy_0=0.454297
# INFO:root:Epoch[13] Batch [60]	Speed: 458.16 samples/sec	Train-multi-accuracy_1=0.007812
# INFO:root:Epoch[13] Batch [60]	Speed: 458.16 samples/sec	Train-multi-accuracy_2=0.250000
# INFO:root:Epoch[13] Batch [80]	Speed: 458.41 samples/sec	Train-multi-accuracy_0=0.458984
# INFO:root:Epoch[13] Batch [80]	Speed: 458.41 samples/sec	Train-multi-accuracy_1=0.010547
# INFO:root:Epoch[13] Batch [80]	Speed: 458.41 samples/sec	Train-multi-accuracy_2=0.350000
# INFO:root:Epoch[13] Batch [100]	Speed: 458.42 samples/sec	Train-multi-accuracy_0=0.448047
# INFO:root:Epoch[13] Batch [100]	Speed: 458.42 samples/sec	Train-multi-accuracy_1=0.007812
# INFO:root:Epoch[13] Batch [100]	Speed: 458.42 samples/sec	Train-multi-accuracy_2=0.412500
# INFO:root:Epoch[13] Batch [120]	Speed: 458.43 samples/sec	Train-multi-accuracy_0=0.450000
# INFO:root:Epoch[13] Batch [120]	Speed: 458.43 samples/sec	Train-multi-accuracy_1=0.007812
# INFO:root:Epoch[13] Batch [120]	Speed: 458.43 samples/sec	Train-multi-accuracy_2=0.325000
# INFO:root:Epoch[13] Batch [140]	Speed: 458.37 samples/sec	Train-multi-accuracy_0=0.440234
# INFO:root:Epoch[13] Batch [140]	Speed: 458.37 samples/sec	Train-multi-accuracy_1=0.010156
# INFO:root:Epoch[13] Batch [140]	Speed: 458.37 samples/sec	Train-multi-accuracy_2=0.325000
# INFO:root:Epoch[13] Batch [160]	Speed: 457.18 samples/sec	Train-multi-accuracy_0=0.448828
# INFO:root:Epoch[13] Batch [160]	Speed: 457.18 samples/sec	Train-multi-accuracy_1=0.009766
# INFO:root:Epoch[13] Batch [160]	Speed: 457.18 samples/sec	Train-multi-accuracy_2=0.400000
# INFO:root:Epoch[13] Batch [180]	Speed: 458.27 samples/sec	Train-multi-accuracy_0=0.448437
# INFO:root:Epoch[13] Batch [180]	Speed: 458.27 samples/sec	Train-multi-accuracy_1=0.008203
# INFO:root:Epoch[13] Batch [180]	Speed: 458.27 samples/sec	Train-multi-accuracy_2=0.425000
# INFO:root:Epoch[13] Train-multi-accuracy_0=0.438616
# INFO:root:Epoch[13] Train-multi-accuracy_1=0.009487
# INFO:root:Epoch[13] Train-multi-accuracy_2=0.339286
# INFO:root:Epoch[13] Time cost=108.653
# INFO:root:Epoch[13] Validation-multi-accuracy_0=0.482572
# INFO:root:Epoch[13] Validation-multi-accuracy_1=0.011418
# INFO:root:Epoch[13] Validation-multi-accuracy_2=0.358974
# INFO:root:Epoch[14] Batch [20]	Speed: 457.91 samples/sec	Train-multi-accuracy_0=0.439732
# INFO:root:Epoch[14] Batch [20]	Speed: 457.91 samples/sec	Train-multi-accuracy_1=0.008929
# INFO:root:Epoch[14] Batch [20]	Speed: 457.91 samples/sec	Train-multi-accuracy_2=0.297619
# INFO:root:Epoch[14] Batch [40]	Speed: 458.37 samples/sec	Train-multi-accuracy_0=0.469922
# INFO:root:Epoch[14] Batch [40]	Speed: 458.37 samples/sec	Train-multi-accuracy_1=0.005859
# INFO:root:Epoch[14] Batch [40]	Speed: 458.37 samples/sec	Train-multi-accuracy_2=0.287500
# INFO:root:Epoch[14] Batch [60]	Speed: 457.82 samples/sec	Train-multi-accuracy_0=0.479687
# INFO:root:Epoch[14] Batch [60]	Speed: 457.82 samples/sec	Train-multi-accuracy_1=0.008203
# INFO:root:Epoch[14] Batch [60]	Speed: 457.82 samples/sec	Train-multi-accuracy_2=0.375000
# INFO:root:Epoch[14] Batch [80]	Speed: 457.87 samples/sec	Train-multi-accuracy_0=0.458203
# INFO:root:Epoch[14] Batch [80]	Speed: 457.87 samples/sec	Train-multi-accuracy_1=0.009375
# INFO:root:Epoch[14] Batch [80]	Speed: 457.87 samples/sec	Train-multi-accuracy_2=0.212500
# INFO:root:Epoch[14] Batch [100]	Speed: 458.04 samples/sec	Train-multi-accuracy_0=0.476562
# INFO:root:Epoch[14] Batch [100]	Speed: 458.04 samples/sec	Train-multi-accuracy_1=0.007422
# INFO:root:Epoch[14] Batch [100]	Speed: 458.04 samples/sec	Train-multi-accuracy_2=0.337500
# INFO:root:Epoch[14] Batch [120]	Speed: 457.79 samples/sec	Train-multi-accuracy_0=0.446875
# INFO:root:Epoch[14] Batch [120]	Speed: 457.79 samples/sec	Train-multi-accuracy_1=0.009766
# INFO:root:Epoch[14] Batch [120]	Speed: 457.79 samples/sec	Train-multi-accuracy_2=0.387500
# INFO:root:Epoch[14] Batch [140]	Speed: 457.62 samples/sec	Train-multi-accuracy_0=0.465625
# INFO:root:Epoch[14] Batch [140]	Speed: 457.62 samples/sec	Train-multi-accuracy_1=0.012109
# INFO:root:Epoch[14] Batch [140]	Speed: 457.62 samples/sec	Train-multi-accuracy_2=0.287500
# INFO:root:Epoch[14] Batch [160]	Speed: 458.10 samples/sec	Train-multi-accuracy_0=0.469922
# INFO:root:Epoch[14] Batch [160]	Speed: 458.10 samples/sec	Train-multi-accuracy_1=0.008203
# INFO:root:Epoch[14] Batch [160]	Speed: 458.10 samples/sec	Train-multi-accuracy_2=0.287500
# INFO:root:Epoch[14] Batch [180]	Speed: 458.67 samples/sec	Train-multi-accuracy_0=0.481641
# INFO:root:Epoch[14] Batch [180]	Speed: 458.67 samples/sec	Train-multi-accuracy_1=0.014453
# INFO:root:Epoch[14] Batch [180]	Speed: 458.67 samples/sec	Train-multi-accuracy_2=0.325000
# INFO:root:Epoch[14] Train-multi-accuracy_0=0.489955
# INFO:root:Epoch[14] Train-multi-accuracy_1=0.010045
# INFO:root:Epoch[14] Train-multi-accuracy_2=0.339286
# INFO:root:Epoch[14] Time cost=108.655
# INFO:root:Epoch[14] Validation-multi-accuracy_0=0.491186
# INFO:root:Epoch[14] Validation-multi-accuracy_1=0.010016
# INFO:root:Epoch[14] Validation-multi-accuracy_2=0.294872
# INFO:root:Epoch[15] Batch [20]	Speed: 457.99 samples/sec	Train-multi-accuracy_0=0.484747
# INFO:root:Epoch[15] Batch [20]	Speed: 457.99 samples/sec	Train-multi-accuracy_1=0.008929
# INFO:root:Epoch[15] Batch [20]	Speed: 457.99 samples/sec	Train-multi-accuracy_2=0.392857
# INFO:root:Epoch[15] Batch [40]	Speed: 458.06 samples/sec	Train-multi-accuracy_0=0.471094
# INFO:root:Epoch[15] Batch [40]	Speed: 458.06 samples/sec	Train-multi-accuracy_1=0.011719
# INFO:root:Epoch[15] Batch [40]	Speed: 458.06 samples/sec	Train-multi-accuracy_2=0.375000
# INFO:root:Epoch[15] Batch [60]	Speed: 457.94 samples/sec	Train-multi-accuracy_0=0.472266
# INFO:root:Epoch[15] Batch [60]	Speed: 457.94 samples/sec	Train-multi-accuracy_1=0.009766
# INFO:root:Epoch[15] Batch [60]	Speed: 457.94 samples/sec	Train-multi-accuracy_2=0.237500
# INFO:root:Batch:    3001 loss_aba_backward_data         0.0823034
# INFO:root:Batch:    3001 loss_aba_backward_label        0.0741028
# INFO:root:Batch:    3001 p_aba_backward_0               0.0782989
# INFO:root:Batch:    3001 p_aba_backward_1               0.0779563
# INFO:root:Batch:    3001 loss_aba_backward_data         0.0772555
# INFO:root:Batch:    3001 loss_aba_backward_label        0.0653744
# INFO:root:Batch:    3001 p_aba_backward_0               0.0703908
# INFO:root:Batch:    3001 p_aba_backward_1               0.0728159
# INFO:root:Batch:    3001 loss_aba_backward_data         0.0750397
# INFO:root:Batch:    3001 loss_aba_backward_label        0.0738184
# INFO:root:Batch:    3001 p_aba_backward_0               0.0690416
# INFO:root:Batch:    3001 p_aba_backward_1               0.0711704
# INFO:root:Batch:    3001 loss_aba_backward_data         0.0780952
# INFO:root:Batch:    3001 loss_aba_backward_label        0.0716337
# INFO:root:Batch:    3001 p_aba_backward_0               0.0759373
# INFO:root:Batch:    3001 p_aba_backward_1               0.0690142
# INFO:root:Epoch[15] Batch [80]	Speed: 456.98 samples/sec	Train-multi-accuracy_0=0.482812
# INFO:root:Epoch[15] Batch [80]	Speed: 456.98 samples/sec	Train-multi-accuracy_1=0.010156
# INFO:root:Epoch[15] Batch [80]	Speed: 456.98 samples/sec	Train-multi-accuracy_2=0.275000
# INFO:root:Epoch[15] Batch [100]	Speed: 457.56 samples/sec	Train-multi-accuracy_0=0.473828
# INFO:root:Epoch[15] Batch [100]	Speed: 457.56 samples/sec	Train-multi-accuracy_1=0.006641
# INFO:root:Epoch[15] Batch [100]	Speed: 457.56 samples/sec	Train-multi-accuracy_2=0.250000
# INFO:root:Epoch[15] Batch [120]	Speed: 458.02 samples/sec	Train-multi-accuracy_0=0.482031
# INFO:root:Epoch[15] Batch [120]	Speed: 458.02 samples/sec	Train-multi-accuracy_1=0.008203
# INFO:root:Epoch[15] Batch [120]	Speed: 458.02 samples/sec	Train-multi-accuracy_2=0.475000
# INFO:root:Epoch[15] Batch [140]	Speed: 458.39 samples/sec	Train-multi-accuracy_0=0.489063
# INFO:root:Epoch[15] Batch [140]	Speed: 458.39 samples/sec	Train-multi-accuracy_1=0.012500
# INFO:root:Epoch[15] Batch [140]	Speed: 458.39 samples/sec	Train-multi-accuracy_2=0.362500
# INFO:root:Epoch[15] Batch [160]	Speed: 458.21 samples/sec	Train-multi-accuracy_0=0.472656
# INFO:root:Epoch[15] Batch [160]	Speed: 458.21 samples/sec	Train-multi-accuracy_1=0.010937
# INFO:root:Epoch[15] Batch [160]	Speed: 458.21 samples/sec	Train-multi-accuracy_2=0.262500
# INFO:root:Epoch[15] Batch [180]	Speed: 457.75 samples/sec	Train-multi-accuracy_0=0.468359
# INFO:root:Epoch[15] Batch [180]	Speed: 457.75 samples/sec	Train-multi-accuracy_1=0.011719
# INFO:root:Epoch[15] Batch [180]	Speed: 457.75 samples/sec	Train-multi-accuracy_2=0.362500
# INFO:root:Epoch[15] Train-multi-accuracy_0=0.486607
# INFO:root:Epoch[15] Train-multi-accuracy_1=0.012835
# INFO:root:Epoch[15] Train-multi-accuracy_2=0.267857
# INFO:root:Epoch[15] Time cost=108.686
# INFO:root:Epoch[15] Validation-multi-accuracy_0=0.501803
# INFO:root:Epoch[15] Validation-multi-accuracy_1=0.008814
# INFO:root:Epoch[15] Validation-multi-accuracy_2=0.333333
# INFO:root:Epoch[16] Batch [20]	Speed: 455.20 samples/sec	Train-multi-accuracy_0=0.473958
# INFO:root:Epoch[16] Batch [20]	Speed: 455.20 samples/sec	Train-multi-accuracy_1=0.011533
# INFO:root:Epoch[16] Batch [20]	Speed: 455.20 samples/sec	Train-multi-accuracy_2=0.380952
# INFO:root:Epoch[16] Batch [40]	Speed: 458.05 samples/sec	Train-multi-accuracy_0=0.485547
# INFO:root:Epoch[16] Batch [40]	Speed: 458.05 samples/sec	Train-multi-accuracy_1=0.014063
# INFO:root:Epoch[16] Batch [40]	Speed: 458.05 samples/sec	Train-multi-accuracy_2=0.350000
# INFO:root:Epoch[16] Batch [60]	Speed: 458.46 samples/sec	Train-multi-accuracy_0=0.481641
# INFO:root:Epoch[16] Batch [60]	Speed: 458.46 samples/sec	Train-multi-accuracy_1=0.010156
# INFO:root:Epoch[16] Batch [60]	Speed: 458.46 samples/sec	Train-multi-accuracy_2=0.337500
# INFO:root:Epoch[16] Batch [80]	Speed: 457.93 samples/sec	Train-multi-accuracy_0=0.492578
# INFO:root:Epoch[16] Batch [80]	Speed: 457.93 samples/sec	Train-multi-accuracy_1=0.007422
# INFO:root:Epoch[16] Batch [80]	Speed: 457.93 samples/sec	Train-multi-accuracy_2=0.362500
# INFO:root:Epoch[16] Batch [100]	Speed: 458.20 samples/sec	Train-multi-accuracy_0=0.484766
# INFO:root:Epoch[16] Batch [100]	Speed: 458.20 samples/sec	Train-multi-accuracy_1=0.008594
# INFO:root:Epoch[16] Batch [100]	Speed: 458.20 samples/sec	Train-multi-accuracy_2=0.187500
# INFO:root:Epoch[16] Batch [120]	Speed: 458.26 samples/sec	Train-multi-accuracy_0=0.485938
# INFO:root:Epoch[16] Batch [120]	Speed: 458.26 samples/sec	Train-multi-accuracy_1=0.008594
# INFO:root:Epoch[16] Batch [120]	Speed: 458.26 samples/sec	Train-multi-accuracy_2=0.287500
# INFO:root:Epoch[16] Batch [140]	Speed: 457.89 samples/sec	Train-multi-accuracy_0=0.472656
# INFO:root:Epoch[16] Batch [140]	Speed: 457.89 samples/sec	Train-multi-accuracy_1=0.012109
# INFO:root:Epoch[16] Batch [140]	Speed: 457.89 samples/sec	Train-multi-accuracy_2=0.362500
# INFO:root:Epoch[16] Batch [160]	Speed: 457.89 samples/sec	Train-multi-accuracy_0=0.495312
# INFO:root:Epoch[16] Batch [160]	Speed: 457.89 samples/sec	Train-multi-accuracy_1=0.014063
# INFO:root:Epoch[16] Batch [160]	Speed: 457.89 samples/sec	Train-multi-accuracy_2=0.387500
# INFO:root:Epoch[16] Batch [180]	Speed: 457.99 samples/sec	Train-multi-accuracy_0=0.501172
# INFO:root:Epoch[16] Batch [180]	Speed: 457.99 samples/sec	Train-multi-accuracy_1=0.006250
# INFO:root:Epoch[16] Batch [180]	Speed: 457.99 samples/sec	Train-multi-accuracy_2=0.425000
# INFO:root:Epoch[16] Train-multi-accuracy_0=0.477604
# INFO:root:Epoch[16] Train-multi-accuracy_1=0.011979
# INFO:root:Epoch[16] Train-multi-accuracy_2=0.216667
# INFO:root:Epoch[16] Time cost=109.375
# INFO:root:Epoch[16] Validation-multi-accuracy_0=0.487695
# INFO:root:Epoch[16] Validation-multi-accuracy_1=0.008594
# INFO:root:Epoch[16] Validation-multi-accuracy_2=0.293750
# INFO:root:Epoch[17] Batch [20]	Speed: 458.84 samples/sec	Train-multi-accuracy_0=0.513393
# INFO:root:Epoch[17] Batch [20]	Speed: 458.84 samples/sec	Train-multi-accuracy_1=0.011533
# INFO:root:Epoch[17] Batch [20]	Speed: 458.84 samples/sec	Train-multi-accuracy_2=0.404762
# INFO:root:Epoch[17] Batch [40]	Speed: 458.14 samples/sec	Train-multi-accuracy_0=0.490234
# INFO:root:Epoch[17] Batch [40]	Speed: 458.14 samples/sec	Train-multi-accuracy_1=0.011719
# INFO:root:Epoch[17] Batch [40]	Speed: 458.14 samples/sec	Train-multi-accuracy_2=0.350000
# INFO:root:Epoch[17] Batch [60]	Speed: 457.47 samples/sec	Train-multi-accuracy_0=0.508984
# INFO:root:Epoch[17] Batch [60]	Speed: 457.47 samples/sec	Train-multi-accuracy_1=0.014453
# INFO:root:Epoch[17] Batch [60]	Speed: 457.47 samples/sec	Train-multi-accuracy_2=0.287500
# INFO:root:Epoch[17] Batch [80]	Speed: 458.65 samples/sec	Train-multi-accuracy_0=0.494922
# INFO:root:Epoch[17] Batch [80]	Speed: 458.65 samples/sec	Train-multi-accuracy_1=0.009375
# INFO:root:Epoch[17] Batch [80]	Speed: 458.65 samples/sec	Train-multi-accuracy_2=0.287500
# INFO:root:Epoch[17] Batch [100]	Speed: 457.71 samples/sec	Train-multi-accuracy_0=0.495312
# INFO:root:Epoch[17] Batch [100]	Speed: 457.71 samples/sec	Train-multi-accuracy_1=0.008984
# INFO:root:Epoch[17] Batch [100]	Speed: 457.71 samples/sec	Train-multi-accuracy_2=0.362500
# INFO:root:Epoch[17] Batch [120]	Speed: 457.94 samples/sec	Train-multi-accuracy_0=0.495312
# INFO:root:Epoch[17] Batch [120]	Speed: 457.94 samples/sec	Train-multi-accuracy_1=0.010156
# INFO:root:Epoch[17] Batch [120]	Speed: 457.94 samples/sec	Train-multi-accuracy_2=0.387500
# INFO:root:Epoch[17] Batch [140]	Speed: 458.02 samples/sec	Train-multi-accuracy_0=0.502344
# INFO:root:Epoch[17] Batch [140]	Speed: 458.02 samples/sec	Train-multi-accuracy_1=0.007812
# INFO:root:Epoch[17] Batch [140]	Speed: 458.02 samples/sec	Train-multi-accuracy_2=0.187500
# INFO:root:Epoch[17] Batch [160]	Speed: 457.82 samples/sec	Train-multi-accuracy_0=0.512109
# INFO:root:Epoch[17] Batch [160]	Speed: 457.82 samples/sec	Train-multi-accuracy_1=0.008984
# INFO:root:Epoch[17] Batch [160]	Speed: 457.82 samples/sec	Train-multi-accuracy_2=0.275000
# INFO:root:Epoch[17] Batch [180]	Speed: 458.10 samples/sec	Train-multi-accuracy_0=0.486719
# INFO:root:Epoch[17] Batch [180]	Speed: 458.10 samples/sec	Train-multi-accuracy_1=0.010937
# INFO:root:Epoch[17] Batch [180]	Speed: 458.10 samples/sec	Train-multi-accuracy_2=0.300000
# INFO:root:Epoch[17] Train-multi-accuracy_0=0.513951
# INFO:root:Epoch[17] Train-multi-accuracy_1=0.015625
# INFO:root:Epoch[17] Train-multi-accuracy_2=0.250000
# INFO:root:Epoch[17] Time cost=108.645
# INFO:root:Epoch[17] Validation-multi-accuracy_0=0.511418
# INFO:root:Epoch[17] Validation-multi-accuracy_1=0.009615
# INFO:root:Epoch[17] Validation-multi-accuracy_2=0.320513
# INFO:root:Epoch[18] Batch [20]	Speed: 458.05 samples/sec	Train-multi-accuracy_0=0.508929
# INFO:root:Epoch[18] Batch [20]	Speed: 458.05 samples/sec	Train-multi-accuracy_1=0.012649
# INFO:root:Epoch[18] Batch [20]	Speed: 458.05 samples/sec	Train-multi-accuracy_2=0.333333
# INFO:root:Epoch[18] Batch [40]	Speed: 458.45 samples/sec	Train-multi-accuracy_0=0.501172
# INFO:root:Epoch[18] Batch [40]	Speed: 458.45 samples/sec	Train-multi-accuracy_1=0.006250
# INFO:root:Epoch[18] Batch [40]	Speed: 458.45 samples/sec	Train-multi-accuracy_2=0.287500

# %%
# batch 10 train 0.389, valid: 0.40
